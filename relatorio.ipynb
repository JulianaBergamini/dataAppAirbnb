# %%
import pandas as pd
import numpy as np 

airbnb = pd.read_csv('/Users/julianabergamini/Desktop/Projeto Data App Airbnb/listings_bangkok.csv')
airbnb.head(10)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  27934  https://www.airbnb.com/rooms/27934  20211223224555   2021-12-24
# 1  27979  https://www.airbnb.com/rooms/27979  20211223224555   2021-12-24
# 2  28745  https://www.airbnb.com/rooms/28745  20211223224555   2021-12-24
# 3  35780  https://www.airbnb.com/rooms/35780  20211223224555   2021-12-24
# 4  35807  https://www.airbnb.com/rooms/35807  20211223224555   2021-12-24
# 5  48736  https://www.airbnb.com/rooms/48736  20211223224555   2021-12-24
# 6  55681  https://www.airbnb.com/rooms/55681  20211223224555   2021-12-24
# 7  55686  https://www.airbnb.com/rooms/55686  20211223224555   2021-12-24
# 8  59221  https://www.airbnb.com/rooms/59221  20211223224555   2021-12-24
# 9  61000  https://www.airbnb.com/rooms/61000  20211223224555   2021-12-24
#
#                                              name  \
# 0                 Nice room with superb city view
# 1                  Easy going landlord,easy place
# ...

# %%
preco = airbnb['price']
type(preco)
# Out:
# pandas.core.series.Series

# %%
preco.sort_values()
# Out:
# 15494        $0.00
# 12788    $1,000.00
# 6148     $1,000.00
# 420      $1,000.00
# 14563    $1,000.00
#            ...
# 512        $999.00
# 417        $999.00
# 2918       $999.00
# 15832      $999.00
# 9616       $999.00
# Name: price, Length: 17040, dtype: object
